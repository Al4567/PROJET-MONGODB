# %% [markdown]
# #  Projet E-commerce - MongoDB / PyMongo
# ##  Contexte
# - Base NoSQL sous MongoDB
# - Domaine : e-commerce
# - Collections : `produits`, `clients`, `commandes`
# - Hébergement : MongoDB Atlas

# %%
from pymongo import MongoClient,errors
from datetime import datetime

try:
    client = MongoClient("mongodb://localhost:27017/") ## connexion a la base de donnees
    #client = MongoClient("mongodb+srv://appUser:MotDePasseAtlas123@cluster0.9d4zwcs.mongodb.net/Projet_Ecommerce?retryWrites=true&w=majority")
    db = client["Projet_Ecommerce"]
    produits_col = db["produits"]
    clients_col = db["clients"]
    commandes_col = db["commandes"]
    print("Connexion établie avec MongoDB")

except errors.ConnectionFailure as e:
    print("Échec de la connexion MongoDB :", e)
except errors.PyMongoError as e:
    print("Erreur PyMongo :", e)
except Exception as e:
    print("Erreur inattendue :", e)
# Out:
# Connexion établie avec MongoDB

# %% [markdown]
# #  CRUD & requêtes simples

# %%
try:
       # CRUD INSERT 
    # But : Ajouter un produit "Webcam Logitech" .
    # Lecture : Affiche le document inséré. 
    new_product = {
        "nom": "Webcam Logitech",
        "categorie": "Informatique",
        "prix": 69.90,
        "stock": 30
    }
    produits_col.insert_one(new_product)
    print("Produit ajouté :", new_product)




    # CRUD FIND simple
    # But : Lister tous les produits de la catégorie 'Informatique'.
    # Lecture : Affiche les documents correspondant.

    for prod in produits_col.find({"categorie": "Informatique"}):
        print("les produits de la catégorie 'Informatique'sont:")
        print(prod)

    # 
    # CRUD UPDATE
    # But : Incrémenter le stock de la Webcam Logitech de +10.
    # Lecture : Confirmation de la mise à jour.
    # 
    produits_col.update_one(
        {"nom": "Webcam Logitech"},
        {"$inc": {"stock": 10}}
    )
    print(" Stock mis à jour")

    # 
    #  CRUD DELETE
    # But : Supprimer le produit 'Webcam Logitech' du catalogue.
    # Lecture : Confirmation de la suppression.
    # 
    produits_col.delete_one({"nom": "Webcam Logitech"})
    print("Produit supprimé")



    # 
    #  FIND ONE
    # But : Trouver le client nommé 'Jean Dupont'.
    # Lecture : Affiche son document si trouvé.
    # 
    client = clients_col.find_one({"nom": "Laura Dupont"})
    print("le client est:",client)

    # 
    # Projection simple
    # But : Lister les commandes en affichant uniquement le total et la date.
    # Lecture : Affiche les commandes avec champs filtrés.
    # 
    for cmd in commandes_col.find({}, {"total":1, "date_commande":1}):
        print("Liste des commandes en affichant uniquement le total et la date.")
        print(cmd)
        
except errors.PyMongoError as e:
    print("Erreur MongoDB :", e)
except Exception as e:
    print("Erreur inattendue :", e)
# Out:
# Produit ajouté : {'nom': 'Webcam Logitech', 'categorie': 'Informatique', 'prix': 69.9, 'stock': 30, '_id': ObjectId('686ef2dc47deee156d8de5ad')}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a2323965f'), 'nom': 'Casque Bluetooth Sony', 'categorie': 'Informatique', 'prix': 114.58, 'stock': 60}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239660'), 'nom': 'Clavier mécanique RGB', 'categorie': 'Informatique', 'prix': 85.19, 'stock': 59}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239661'), 'nom': 'Écran 27 pouces Samsung', 'categorie': 'Informatique', 'prix': 257.5, 'stock': 72}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239664'), 'nom': 'Écran 27 pouces Samsung', 'categorie': 'Informatique', 'prix': 248.14, 'stock': 37}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239665'), 'nom': 'Clavier mécanique RGB', 'categorie': 'Informatique', 'prix': 79.07, 'stock': 10}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239667'), 'nom': 'Écran 27 pouces Samsung', 'categorie': 'Informatique', 'prix': 206.86, 'stock': 61}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239669'), 'nom': 'Clavier mécanique RGB', 'categorie': 'Informatique', 'prix': 83.82, 'stock': 22}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a2323966c'), 'nom': 'Souris sans fil Logitech', 'categorie': 'Informatique', 'prix': 44.24, 'stock': 65}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a2323966e'), 'nom': 'Écran 27 pouces Samsung', 'categorie': 'Informatique', 'prix': 239.66, 'stock': 88}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239670'), 'nom': 'Clavier mécanique RGB', 'categorie': 'Informatique', 'prix': 102.75, 'stock': 39}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686bc11f6be8a32a23239671'), 'nom': 'Souris sans fil Logitech', 'categorie': 'Informatique', 'prix': 53.8, 'stock': 99}
# les produits de la catégorie 'Informatique'sont:
# {'_id': ObjectId('686ef2dc47deee156d8de5ad'), 'nom': 'Webcam Logitech', 'categorie': 'Informatique', 'prix': 69.9, 'stock': 30}
#  Stock mis à jour
# Produit supprimé
# le client est: {'_id': ObjectId('686bc11f6be8a32a23239672'), 'nom': 'Laura Dupont', 'email': 'laura.dupont@gmail.com', 'adresse': '98 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'total': 1222.17}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'date_commande': datetime.datetime(2025, 7, 6, 0, 0), 'total': 1745.71}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'total': 2440.3}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239689'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'total': 335.28}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'total': 1406.6}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'total': 1968.18}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'total': 3101.76}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968d'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'total': 322.58}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'total': 613.09}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'total': 516.47}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239690'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'total': 958.64}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'total': 83.82}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239692'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'total': 1190.94}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239693'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'total': 413.72}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'total': 1439.02}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'total': 2053.19}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'total': 521.1}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239697'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'total': 1302.6}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'total': 1346.24}
# Liste des commandes en affichant uniquement le total et la date.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'total': 550.08}

# %% [markdown]
# #  Requêtes avancées

# %%
try:
    # 
    #  $and
    # But : Trouver les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com.
    # Lecture : Liste des clients qui satisfont les deux conditions.
    # 
    for client in clients_col.find({
        "$and": [
            {"email": {"$regex": "@gmail.com$"}},
            {"date_inscription": {"$gte": datetime(2025,7,1)}}
        ]
    }):
        print("les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:")
        print(client)

    # 
    #  $or
    # But : Trouver les produits ayant moins de 10 en stock ou coûtant plus de 300€.
    # Lecture : Affiche les produits qui répondent à au moins une condition.
    # 
    for prod in produits_col.find({
        "$or": [
            {"stock": {"$lt": 10}},
            {"prix": {"$gt": 300}}
        ]
    }):
        print("les produits ayant moins de 10 en stock ou coûtant plus de 300€ sont:")
        print(prod)

    # 
    #  $regex
    # But : Lister les clients dont le nom commence par 'J'.
    # Lecture : Affiche tous les clients correspondants.
    # 
    for client in clients_col.find({"nom": {"$regex": "^J"}}):
        print("les clients dont le nom commence par J sont:")
        print(client)

    # 
    #  $in
    # But : Trouver les produits 'Tapis de course' ou 'Aspirateur Dyson'.
    # Lecture : Affiche uniquement ces produits.
    # 
    for prod in produits_col.find({"nom": {"$in": ["Tapis de course", "Aspirateur Dyson"]}}):
        print("les produits 'Tapis de course' ou 'Aspirateur Dyson'")
        print(prod)

    # 
    # $exists
    # But : Lister les commandes qui contiennent bien un champ 'produits'.
    # Lecture : Affiche toutes les commandes valides avec ce champ.
    # 
    for cmd in commandes_col.find({"produits": {"$exists": True}}):
        print("Liste des commandes qui contiennent bien un champ 'produits'. ")
        print(cmd)

    # 
    #  Projection + sort
    # But : Lister les clients triés par date d'inscription décroissante, avec nom et date uniquement.
    # Lecture : Permet de voir les clients  plus récents .
    # 
    for client in clients_col.find({}, {"nom":1, "date_inscription":1}).sort("date_inscription", -1):
        print("Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.")
        print(client)
        
except errors.ConnectionFailure as e:
    print("Échec de la connexion MongoDB :", e)
except errors.PyMongoError as e:
    print("Erreur PyMongo :", e)
except Exception as e:
    print("Erreur inattendue :", e)
# Out:
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239672'), 'nom': 'Laura Dupont', 'email': 'laura.dupont@gmail.com', 'adresse': '98 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239674'), 'nom': 'Paul Petit', 'email': 'paul.petit@gmail.com', 'adresse': '36 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 4, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239675'), 'nom': 'Paul Dupont', 'email': 'paul.dupont@gmail.com', 'adresse': '37 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239676'), 'nom': 'Marie Moreau', 'email': 'marie.moreau@gmail.com', 'adresse': '91 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239677'), 'nom': 'Jean Robert', 'email': 'jean.robert@gmail.com', 'adresse': '38 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239678'), 'nom': 'Jean Dubois', 'email': 'jean.dubois@gmail.com', 'adresse': '53 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239679'), 'nom': 'Paul Robert', 'email': 'paul.robert@gmail.com', 'adresse': '82 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967a'), 'nom': 'Marie Robert', 'email': 'marie.robert@gmail.com', 'adresse': '35 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967b'), 'nom': 'Julie Thomas', 'email': 'julie.thomas@gmail.com', 'adresse': '85 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967c'), 'nom': 'Julie Durand', 'email': 'julie.durand@gmail.com', 'adresse': '60 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967d'), 'nom': 'Pierre Petit', 'email': 'pierre.petit@gmail.com', 'adresse': '62 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967e'), 'nom': 'Emma Moreau', 'email': 'emma.moreau@gmail.com', 'adresse': '31 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967f'), 'nom': 'Luc Petit', 'email': 'luc.petit@gmail.com', 'adresse': '77 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239680'), 'nom': 'Louis Durand', 'email': 'louis.durand@gmail.com', 'adresse': '92 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239681'), 'nom': 'Jean Richard', 'email': 'jean.richard@gmail.com', 'adresse': '18 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239682'), 'nom': 'Paul Bernard', 'email': 'paul.bernard@gmail.com', 'adresse': '6 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239683'), 'nom': 'Paul Petit', 'email': 'paul.petit@gmail.com', 'adresse': '25 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239684'), 'nom': 'Luc Petit', 'email': 'luc.petit@gmail.com', 'adresse': '48 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# les clients inscrits en juillet 2025 avec un email se terminant par @gmail.com sont:
# {'_id': ObjectId('686bc11f6be8a32a23239685'), 'nom': 'Luc Durand', 'email': 'luc.durand@gmail.com', 'adresse': '67 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# les produits ayant moins de 10 en stock ou coûtant plus de 300€ sont:
# {'_id': ObjectId('686bc11f6be8a32a23239663'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 396.98, 'stock': 80}
# les produits ayant moins de 10 en stock ou coûtant plus de 300€ sont:
# {'_id': ObjectId('686bc11f6be8a32a23239666'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 422.13, 'stock': 28}
# les produits ayant moins de 10 en stock ou coûtant plus de 300€ sont:
# {'_id': ObjectId('686bc11f6be8a32a2323966b'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 325.65, 'stock': 39}
# les produits ayant moins de 10 en stock ou coûtant plus de 300€ sont:
# {'_id': ObjectId('686bc11f6be8a32a2323966f'), 'nom': 'Tapis de course', 'categorie': 'Sport', 'prix': 535.78, 'stock': 77}
# les clients dont le nom commence par J sont:
# {'_id': ObjectId('686bc11f6be8a32a23239677'), 'nom': 'Jean Robert', 'email': 'jean.robert@gmail.com', 'adresse': '38 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# les clients dont le nom commence par J sont:
# {'_id': ObjectId('686bc11f6be8a32a23239678'), 'nom': 'Jean Dubois', 'email': 'jean.dubois@gmail.com', 'adresse': '53 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# les clients dont le nom commence par J sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967b'), 'nom': 'Julie Thomas', 'email': 'julie.thomas@gmail.com', 'adresse': '85 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# les clients dont le nom commence par J sont:
# {'_id': ObjectId('686bc11f6be8a32a2323967c'), 'nom': 'Julie Durand', 'email': 'julie.durand@gmail.com', 'adresse': '60 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# les clients dont le nom commence par J sont:
# {'_id': ObjectId('686bc11f6be8a32a23239681'), 'nom': 'Jean Richard', 'email': 'jean.richard@gmail.com', 'adresse': '18 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# les produits 'Tapis de course' ou 'Aspirateur Dyson'
# {'_id': ObjectId('686bc11f6be8a32a23239663'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 396.98, 'stock': 80}
# les produits 'Tapis de course' ou 'Aspirateur Dyson'
# {'_id': ObjectId('686bc11f6be8a32a23239666'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 422.13, 'stock': 28}
# les produits 'Tapis de course' ou 'Aspirateur Dyson'
# {'_id': ObjectId('686bc11f6be8a32a2323966b'), 'nom': 'Aspirateur Dyson', 'categorie': 'Maison', 'prix': 325.65, 'stock': 39}
# les produits 'Tapis de course' ou 'Aspirateur Dyson'
# {'_id': ObjectId('686bc11f6be8a32a2323966f'), 'nom': 'Tapis de course', 'categorie': 'Sport', 'prix': 535.78, 'stock': 77}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'client_id': ObjectId('686bc11f6be8a32a23239681'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 325.65}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}, {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}], 'total': 1222.17}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 6, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 239.66}, {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 422.13}], 'total': 1745.71}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 257.5}, {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}, {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}], 'total': 2440.3}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239689'), 'client_id': ObjectId('686bc11f6be8a32a2323967e'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Clavier mécanique RGB', 'quantite': 4, 'prix_unitaire': 83.82}], 'total': 335.28}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'client_id': ObjectId('686bc11f6be8a32a23239685'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 257.5}, {'nom': 'Souris sans fil Logitech', 'quantite': 4, 'prix_unitaire': 53.8}, {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}], 'total': 1406.6}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}, {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 83.82}, {'nom': 'Montre connectée Garmin', 'quantite': 4, 'prix_unitaire': 161.29}], 'total': 1968.18}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 4, 'prix_unitaire': 535.78}, {'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}], 'total': 3101.76}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968d'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 161.29}], 'total': 322.58}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 1, 'prix_unitaire': 396.98}, {'nom': 'Lampe LED bureau', 'quantite': 3, 'prix_unitaire': 43.64}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 85.19}], 'total': 613.09}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 102.75}], 'total': 516.47}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239690'), 'client_id': ObjectId('686bc11f6be8a32a23239682'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}], 'total': 958.64}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'client_id': ObjectId('686bc11f6be8a32a23239675'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}], 'total': 83.82}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239692'), 'client_id': ObjectId('686bc11f6be8a32a23239685'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}], 'total': 1190.94}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239693'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}], 'total': 413.72}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'client_id': ObjectId('686bc11f6be8a32a2323967f'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}, {'nom': 'Clavier mécanique RGB', 'quantite': 2, 'prix_unitaire': 83.82}, {'nom': 'Lampe LED bureau', 'quantite': 2, 'prix_unitaire': 40.22}], 'total': 1439.02}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'client_id': ObjectId('686bc11f6be8a32a23239680'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}, {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 79.07}, {'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 248.14}], 'total': 2053.19}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'client_id': ObjectId('686bc11f6be8a32a23239672'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 44.24}, {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}], 'total': 521.1}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239697'), 'client_id': ObjectId('686bc11f6be8a32a2323967d'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}], 'total': 1302.6}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}, {'nom': 'Lampe LED bureau', 'quantite': 1, 'prix_unitaire': 43.64}], 'total': 1346.24}
# Liste des commandes qui contiennent bien un champ 'produits'.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'client_id': ObjectId('686bc11f6be8a32a2323967b'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 248.14}, {'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 53.8}], 'total': 550.08}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967f'), 'nom': 'Luc Petit', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239681'), 'nom': 'Jean Richard', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239682'), 'nom': 'Paul Bernard', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967b'), 'nom': 'Julie Thomas', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967e'), 'nom': 'Emma Moreau', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239674'), 'nom': 'Paul Petit', 'date_inscription': datetime.datetime(2025, 7, 4, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239675'), 'nom': 'Paul Dupont', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239676'), 'nom': 'Marie Moreau', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967c'), 'nom': 'Julie Durand', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239685'), 'nom': 'Luc Durand', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239672'), 'nom': 'Laura Dupont', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239678'), 'nom': 'Jean Dubois', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967a'), 'nom': 'Marie Robert', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239680'), 'nom': 'Louis Durand', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239683'), 'nom': 'Paul Petit', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239677'), 'nom': 'Jean Robert', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239679'), 'nom': 'Paul Robert', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a2323967d'), 'nom': 'Pierre Petit', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}
# Liste des clients triés par date d'inscription décroissante, avec nom et date uniquement.
# {'_id': ObjectId('686bc11f6be8a32a23239684'), 'nom': 'Luc Petit', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}

# %% [markdown]
# # Agrégations

# %%
try:
    # 
    # $group
    # But : Calculer le total dépensé par chaque client.
    # Lecture : Affiche un document par client avec son total.
    # 
    pipeline = [
        {"$group": {"_id": "$client_id", "total_depense": {"$sum": "$total"}}}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("le total dépensé par chaque client.")
        print(doc)



    # 
    #  $group + $sort + $limit
    # But : Obtenir le top 3 des clients qui ont le plus dépensé.
    # Lecture : Classement décroissant par total.
    # 
    pipeline = [
        {"$group": {"_id": "$client_id", "total_depense": {"$sum": "$total"}}},
        {"$sort": {"total_depense": -1}},
        {"$limit": 3}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("top 3 des clients qui ont le plus dépensé.")
        print(doc)
        
    


    # 
    #  $project
    # But : Afficher les commandes avec un champ TVA calculé à 20%.
    # Lecture : Nouveau champ 'TVA' visible dans les résultats.
    # 
    pipeline = [
        {"$project": {"total":1, "TVA": {"$multiply": ["$total", 0.2]}}}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("Affichage des commandes avec un champ TVA calculé à 20%.")
        print(doc)



    # 
    #  $lookup
    # But : Faire une jointure pour enrichir les commandes avec les infos clients.
    # Lecture : Ajoute un tableau 'client_info' avec le client correspondant.
    # 
    pipeline = [
        {"$lookup": {
            "from": "clients",
            "localField": "client_id",
            "foreignField": "_id",
            "as": "client_info"
        }}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("Ajoute un tableau 'client_info' avec le client correspondant.")
        print(doc)



    # 
    # $unwind
    # But : Éclater le tableau 'produits' pour avoir un document par produit commandé.
    # Lecture : Chaque produit est sur une ligne différente.
    # 
    pipeline = [
        {"$unwind": "$produits"},
        {"$project": {"produits":1}}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("document par produit commandé.")
        print(doc)




    # 
    # $unwind + $group
    # But : Compter combien de fois chaque produit a été commandé.
    # Lecture : Affiche le nombre de commandes par produit.
    # 
    pipeline = [
        {"$unwind": "$produits"},
        {"$group": {"_id": "$produits.nom", "nb_commandes": {"$sum": 1}}},
        {"$sort": {"nb_commandes": -1}}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("Nombre de fois chaque produit a été commandé.")
        print(doc)
        



    # 
    # $group stats globales
    # But : Calculer le total et la moyenne des montants commandés.
    # Lecture : Donne deux indicateurs globaux sur toutes les commandes.
    # 
    pipeline = [
        {"$group": {
            "_id": None,
            "total_commande": {"$sum": "$total"},
            "moyenne_commande": {"$avg": "$total"}
        }}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("le total et la moyenne des montants commandés.")
        print(doc)




    # 
    #  $lookup + $unwind + $match
    # But : Trouver les commandes dont le client a un email contenant 'dupont'.
    # Lecture : Combine jointure et filtrage sur le champ client.
    # 
    pipeline = [
        {"$lookup": {
            "from": "clients",
            "localField": "client_id",
            "foreignField": "_id",
            "as": "client_info"
        }},
        {"$unwind": "$client_info"},
        {"$match": {"client_info.email": {"$regex": "dupont"}}}
    ]
    for doc in commandes_col.aggregate(pipeline):
        print("les commandes dont le client a un email contenant 'dupont'.")
        print(doc)
        
except errors.ConnectionFailure as e:
    print("Échec de la connexion MongoDB :", e)
except errors.PyMongoError as e:
    print("Erreur PyMongo :", e)
except Exception as e:
    print("Erreur inattendue :", e)
# Out:
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239682'), 'total_depense': 958.64}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a2323967f'), 'total_depense': 1439.02}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239673'), 'total_depense': 8165.04}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239672'), 'total_depense': 521.1}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a2323967b'), 'total_depense': 550.08}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239680'), 'total_depense': 2053.19}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239676'), 'total_depense': 4303.01}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a2323967e'), 'total_depense': 335.28}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239685'), 'total_depense': 2597.54}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239681'), 'total_depense': 1222.17}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a2323967d'), 'total_depense': 1302.6}
# le total dépensé par chaque client.
# {'_id': ObjectId('686bc11f6be8a32a23239675'), 'total_depense': 83.82}
# top 3 des clients qui ont le plus dépensé.
# {'_id': ObjectId('686bc11f6be8a32a23239673'), 'total_depense': 8165.04}
# top 3 des clients qui ont le plus dépensé.
# {'_id': ObjectId('686bc11f6be8a32a23239676'), 'total_depense': 4303.01}
# top 3 des clients qui ont le plus dépensé.
# {'_id': ObjectId('686bc11f6be8a32a23239685'), 'total_depense': 2597.54}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'total': 1222.17, 'TVA': 244.43400000000003}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'total': 1745.71, 'TVA': 349.14200000000005}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'total': 2440.3, 'TVA': 488.06000000000006}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239689'), 'total': 335.28, 'TVA': 67.056}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'total': 1406.6, 'TVA': 281.32}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'total': 1968.18, 'TVA': 393.636}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'total': 3101.76, 'TVA': 620.3520000000001}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968d'), 'total': 322.58, 'TVA': 64.516}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'total': 613.09, 'TVA': 122.61800000000001}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'total': 516.47, 'TVA': 103.29400000000001}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239690'), 'total': 958.64, 'TVA': 191.728}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'total': 83.82, 'TVA': 16.764}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239692'), 'total': 1190.94, 'TVA': 238.18800000000002}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239693'), 'total': 413.72, 'TVA': 82.74400000000001}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'total': 1439.02, 'TVA': 287.80400000000003}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'total': 2053.19, 'TVA': 410.63800000000003}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'total': 521.1, 'TVA': 104.22000000000001}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239697'), 'total': 1302.6, 'TVA': 260.52}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'total': 1346.24, 'TVA': 269.248}
# Affichage des commandes avec un champ TVA calculé à 20%.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'total': 550.08, 'TVA': 110.01600000000002}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'client_id': ObjectId('686bc11f6be8a32a23239681'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 325.65}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}, {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}], 'total': 1222.17, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239681'), 'nom': 'Jean Richard', 'email': 'jean.richard@gmail.com', 'adresse': '18 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 6, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 239.66}, {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 422.13}], 'total': 1745.71, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 257.5}, {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}, {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}], 'total': 2440.3, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239676'), 'nom': 'Marie Moreau', 'email': 'marie.moreau@gmail.com', 'adresse': '91 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239689'), 'client_id': ObjectId('686bc11f6be8a32a2323967e'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Clavier mécanique RGB', 'quantite': 4, 'prix_unitaire': 83.82}], 'total': 335.28, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a2323967e'), 'nom': 'Emma Moreau', 'email': 'emma.moreau@gmail.com', 'adresse': '31 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'client_id': ObjectId('686bc11f6be8a32a23239685'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 257.5}, {'nom': 'Souris sans fil Logitech', 'quantite': 4, 'prix_unitaire': 53.8}, {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}], 'total': 1406.6, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239685'), 'nom': 'Luc Durand', 'email': 'luc.durand@gmail.com', 'adresse': '67 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}, {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 83.82}, {'nom': 'Montre connectée Garmin', 'quantite': 4, 'prix_unitaire': 161.29}], 'total': 1968.18, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 4, 'prix_unitaire': 535.78}, {'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}], 'total': 3101.76, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968d'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 161.29}], 'total': 322.58, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 1, 'prix_unitaire': 396.98}, {'nom': 'Lampe LED bureau', 'quantite': 3, 'prix_unitaire': 43.64}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 85.19}], 'total': 613.09, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 5, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}, {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 102.75}], 'total': 516.47, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239676'), 'nom': 'Marie Moreau', 'email': 'marie.moreau@gmail.com', 'adresse': '91 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239690'), 'client_id': ObjectId('686bc11f6be8a32a23239682'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}], 'total': 958.64, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239682'), 'nom': 'Paul Bernard', 'email': 'paul.bernard@gmail.com', 'adresse': '6 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'client_id': ObjectId('686bc11f6be8a32a23239675'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}], 'total': 83.82, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239675'), 'nom': 'Paul Dupont', 'email': 'paul.dupont@gmail.com', 'adresse': '37 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239692'), 'client_id': ObjectId('686bc11f6be8a32a23239685'), 'date_commande': datetime.datetime(2025, 7, 4, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}], 'total': 1190.94, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239685'), 'nom': 'Luc Durand', 'email': 'luc.durand@gmail.com', 'adresse': '67 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239693'), 'client_id': ObjectId('686bc11f6be8a32a23239673'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}], 'total': 413.72, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239673'), 'nom': 'Laura Robert', 'email': 'laura.robert@gmail.com', 'adresse': '100 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'client_id': ObjectId('686bc11f6be8a32a2323967f'), 'date_commande': datetime.datetime(2025, 7, 1, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}, {'nom': 'Clavier mécanique RGB', 'quantite': 2, 'prix_unitaire': 83.82}, {'nom': 'Lampe LED bureau', 'quantite': 2, 'prix_unitaire': 40.22}], 'total': 1439.02, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a2323967f'), 'nom': 'Luc Petit', 'email': 'luc.petit@gmail.com', 'adresse': '77 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 6, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'client_id': ObjectId('686bc11f6be8a32a23239680'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}, {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 79.07}, {'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 248.14}], 'total': 2053.19, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239680'), 'nom': 'Louis Durand', 'email': 'louis.durand@gmail.com', 'adresse': '92 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'client_id': ObjectId('686bc11f6be8a32a23239672'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 44.24}, {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}], 'total': 521.1, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239672'), 'nom': 'Laura Dupont', 'email': 'laura.dupont@gmail.com', 'adresse': '98 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239697'), 'client_id': ObjectId('686bc11f6be8a32a2323967d'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}], 'total': 1302.6, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a2323967d'), 'nom': 'Pierre Petit', 'email': 'pierre.petit@gmail.com', 'adresse': '62 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 1, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'client_id': ObjectId('686bc11f6be8a32a23239676'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}, {'nom': 'Lampe LED bureau', 'quantite': 1, 'prix_unitaire': 43.64}], 'total': 1346.24, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a23239676'), 'nom': 'Marie Moreau', 'email': 'marie.moreau@gmail.com', 'adresse': '91 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}]}
# Ajoute un tableau 'client_info' avec le client correspondant.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'client_id': ObjectId('686bc11f6be8a32a2323967b'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 248.14}, {'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 53.8}], 'total': 550.08, 'client_info': [{'_id': ObjectId('686bc11f6be8a32a2323967b'), 'nom': 'Julie Thomas', 'email': 'julie.thomas@gmail.com', 'adresse': '85 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 5, 0, 0)}]}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 325.65}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239686'), 'produits': {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 239.66}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239687'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 422.13}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 257.5}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239688'), 'produits': {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239689'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 4, 'prix_unitaire': 83.82}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 257.5}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'produits': {'nom': 'Souris sans fil Logitech', 'quantite': 4, 'prix_unitaire': 53.8}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968a'), 'produits': {'nom': 'Souris sans fil Logitech', 'quantite': 3, 'prix_unitaire': 53.8}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'produits': {'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 83.82}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968b'), 'produits': {'nom': 'Montre connectée Garmin', 'quantite': 4, 'prix_unitaire': 161.29}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'produits': {'nom': 'Tapis de course', 'quantite': 4, 'prix_unitaire': 535.78}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968c'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968d'), 'produits': {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 161.29}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 1, 'prix_unitaire': 396.98}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'produits': {'nom': 'Lampe LED bureau', 'quantite': 3, 'prix_unitaire': 43.64}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968e'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 85.19}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a2323968f'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 102.75}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239690'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 4, 'prix_unitaire': 239.66}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239692'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239693'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 206.86}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 3, 'prix_unitaire': 396.98}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 2, 'prix_unitaire': 83.82}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239694'), 'produits': {'nom': 'Lampe LED bureau', 'quantite': 2, 'prix_unitaire': 40.22}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'produits': {'nom': 'Tapis de course', 'quantite': 2, 'prix_unitaire': 535.78}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'produits': {'nom': 'Clavier mécanique RGB', 'quantite': 3, 'prix_unitaire': 79.07}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239695'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 3, 'prix_unitaire': 248.14}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'produits': {'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 44.24}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'produits': {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239697'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'produits': {'nom': 'Aspirateur Dyson', 'quantite': 4, 'prix_unitaire': 325.65}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239698'), 'produits': {'nom': 'Lampe LED bureau', 'quantite': 1, 'prix_unitaire': 43.64}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'produits': {'nom': 'Écran 27 pouces Samsung', 'quantite': 2, 'prix_unitaire': 248.14}}
# document par produit commandé.
# {'_id': ObjectId('686bc11f6be8a32a23239699'), 'produits': {'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 53.8}}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Écran 27 pouces Samsung', 'nb_commandes': 9}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Aspirateur Dyson', 'nb_commandes': 8}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Clavier mécanique RGB', 'nb_commandes': 8}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Souris sans fil Logitech', 'nb_commandes': 5}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Montre connectée Garmin', 'nb_commandes': 4}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Lampe LED bureau', 'nb_commandes': 3}
# Nombre de fois chaque produit a été commandé.
# {'_id': 'Tapis de course', 'nb_commandes': 3}
# le total et la moyenne des montants commandés.
# {'_id': None, 'total_commande': 23531.49, 'moyenne_commande': 1176.5745000000002}
# les commandes dont le client a un email contenant 'dupont'.
# {'_id': ObjectId('686bc11f6be8a32a23239691'), 'client_id': ObjectId('686bc11f6be8a32a23239675'), 'date_commande': datetime.datetime(2025, 7, 3, 0, 0), 'produits': [{'nom': 'Clavier mécanique RGB', 'quantite': 1, 'prix_unitaire': 83.82}], 'total': 83.82, 'client_info': {'_id': ObjectId('686bc11f6be8a32a23239675'), 'nom': 'Paul Dupont', 'email': 'paul.dupont@gmail.com', 'adresse': '37 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 3, 0, 0)}}
# les commandes dont le client a un email contenant 'dupont'.
# {'_id': ObjectId('686bc11f6be8a32a23239696'), 'client_id': ObjectId('686bc11f6be8a32a23239672'), 'date_commande': datetime.datetime(2025, 7, 2, 0, 0), 'produits': [{'nom': 'Souris sans fil Logitech', 'quantite': 1, 'prix_unitaire': 44.24}, {'nom': 'Montre connectée Garmin', 'quantite': 2, 'prix_unitaire': 238.43}], 'total': 521.1, 'client_info': {'_id': ObjectId('686bc11f6be8a32a23239672'), 'nom': 'Laura Dupont', 'email': 'laura.dupont@gmail.com', 'adresse': '98 rue Exemple, Ville', 'date_inscription': datetime.datetime(2025, 7, 2, 0, 0)}}
